# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os

# %%
os.getcwd()
# Out:
# '/Users/swapnendu.majumdar/Downloads'

# %%
os.chdir("/Users/swapnendu.majumdar/Downloads")

# %%
transaction_data=pd.read_excel('Fraud_Analytics_Dataset.xlsx',0)
customer_data=pd.read_excel('Fraud_Analytics_Dataset.xlsx',1)
sales_data=pd.read_excel('Fraud_Analytics_Dataset.xlsx',2)

# %%
display(transaction_data.head())
display(customer_data.head())
display(sales_data.head())
# Out:
#    Transaction_Id First Time Customers.  Bigger than Average Orders.   \
# 0          235360                     No                           No
# 1          234773                     No                           No
# 2          235242                     No                           No
# 3          235350                     No                          Yes
# 4          234914                     No                           No
#
#   Fast Shipping  Unusual Location.  Large quantity of Same Product .   \
# 0             No                 No                                No
# 1             No                 No                                No
# 2             No                 No                                No
# 3            Yes                 No                                No
# 4             No                 No                                No
#
#    Multiple Shipping Addresses.  \
# 0                            No
# 1                            No
# 2                            No
# 3                           Yes
# 4                            No
#
#   Shipping and Billing Address are not the same.  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                            Yes
# 4                                             No
#
#   Several Cards used from the Same Ip Address.  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                          Yes
# 4                                           No
#
#   Payment Information typed with Capital letters.   \
# 0                                               No
# 1                                               No
# 2                                               No
# 3                                              Yes
# 4                                               No
#
#   Many Transactions in a short time period.
# 0                                         No
# 1                                         No
# 2                                         No
# 3                                        Yes
# 4                                         No
#    CUSTOMER_ID LOYALTY_ID  MEMBERSHIP_TYPE__ID MEMBERSHIP_TYPE  \
# 0     76565665  LID877073                901.0            Gold
# 1     76565666  LID877029                  NaN             NaN
# 2     76565667  LID876876                902.0          Silver
# 3     76565668  LID876841                902.0          Silver
# 4     76565669  LID877001                902.0          Silver
#
#   MEMBERSHIP_TYPE_SC CUSTOMER_FLG            Customer_Type  customer_type_id  \
# 0                GLD            Y  Small/Medium Enterprise            1002.0
# 1                NaN            Y               Individual            1003.0
# 2                SLV            Y  Small/Medium Enterprise            1002.0
# 3                SLV            Y  Small/Medium Enterprise            1002.0
# 4                SLV            Y               Individual            1003.0
#
#   customer_type_sc behavior_segment        ...         BIRTH_MONTH  \
# 0              ENT       High Value        ...               April
# 1             INDV        Low Value        ...            December
# 2              ENT     Medium Value        ...            February
# 3              ENT        Low Value        ...            December
# 4             INDV     Medium Value        ...             January
#
#    BIRTH_YEAR BIRTH_QUARTER PLACE_OF_BIRTH COUNTRY_OF_BIRTH_SC  \
# 0        2004             2       Bellevue                  US
# 1        1984             4        Jackson                  US
# 2        1999             1    Chattanooga                  US
# 3        1997             4      Worcester                  US
# 4        1992             1    Los Angeles                  US
#
#    EVER_BANKRUPT_FLG  NO_TIMES_DELINQUENT_in_365_days BLACKLISTED_FLG  \
# 0                  N                                1               N
# 1                  N                                1               N
# 2                  N                                1               N
# 3                  N                                0               N
# 4                  N                                1               N
#
#   NO_OF_DEPENDANTS  Record_created_By
# 0                3                 \r
# 1                1                 \r
# 2                3                 \r
# 3                1                 \r
# 4                1                 \r
#
# [5 rows x 94 columns]
#    Transaction_Id  Invoice_Id  Order_Id  Customer_Id  Mdm_Customer_Id  \
# 0          234825       88371     88371     76565900        954421840
# 1          234666       88234     88234     76566122        965982087
# 2          234823       88153     88153     76565906        953091566
# 3          235342       87867     87867     76566458        924245622
# 4          234739       87945     87945     76566387        966653489
#
#   Loyalty_Id  Gender  Age  Membership_Id Membership_Type  ...   \
# 0  LID876561  FEMALE   26          904.0        Platinum  ...
# 1        NaN    MALE   22            NaN             NaN  ...
# 2  LID876543    MALE   19          904.0        Platinum  ...
# 3  LID876557    MALE   26          901.0            Gold  ...
# 4  LID876640    MALE   37          901.0            Gold  ...
#
#   Cancel_Reason_Code  Cancel_Description  Return_Flag  Return_Dt Return_Amt  \
# 0                  0                 NaN            Y 2016-05-08       1953
# 1                  0                 NaN            N 2016-04-26          0
# 2                  0                 NaN            N 2016-05-16          0
# 3                  0                 NaN            N 2016-05-14          0
# 4                  0                 NaN            Y 2016-05-26       1322
#
#    Order_Returnpaid_Gross_Amt  Lastmodified_Dt  Sales_Rep_Name  Sales_Rep_Id  \
# 0                        1406       2016-04-01             NaN            \r
# 1                           0       2016-11-14             NaN            \r
# 2                           0       2016-08-25            John        S101\r
# 3                           0       2016-04-17             NaN            \r
# 4                         952       2016-07-04            John        S101\r
#
#   Fraud
# 0    No
# 1   Yes
# 2    No
# 3    No
# 4   Yes
#
# [5 rows x 54 columns]

# %%
#Column Names
#transaction_data.columns
#customer_data.columns
#sales_data.columns

'''
Index([u'Transaction_Id', u'First Time Customers. ',
       u'Bigger than Average Orders. ', u'Fast Shipping ',
       u'Unusual Location. ', u'Large quantity of Same Product . ',
       u' Multiple Shipping Addresses.',
       u'Shipping and Billing Address are not the same.',
       u'Several Cards used from the Same Ip Address.',
       u'Payment Information typed with Capital letters. ',
       u'Many Transactions in a short time period. '],
      dtype='object')
'''
'''
Index([u'CUSTOMER_ID', u'LOYALTY_ID', u'MEMBERSHIP_TYPE__ID',
       u'MEMBERSHIP_TYPE', u'MEMBERSHIP_TYPE_SC', u'CUSTOMER_FLG',
       u'Customer_Type', u'customer_type_id', u'customer_type_sc',
       u'behavior_segment', u'SALUTATION', u'GENDER_ID', u'GENDER',
       u'GENDER_SC', u'BIRTH_DATE', u'AGE', u'age_at_joining', u'age_range',
       u'PLACE_OF_BITRH', u'CUSTOMER_STATUS_ID', u'CUSTOMER_STATUS_SC',
       u'CUSTOMER_STATUS', u'CUSTOMER_CREATED_DT', u'LOYALITY_FLG',
       u'DEVICE_ID', u'APP_ID', u'MARITAL_STATUS_ID', u'MARITAL_STATUS',
       u'MARITAL_STATUS_SC', u'ANNIVERSARY_DT', u'INCOME_RANGE', u'INCOME',
       u'PROFESSION', u'PROFESSION_TYPE_SC', u'PROFESSION_TYPE_ID',
       u'education', u'REGION', u'LANGUAGE', u'PREF_COMM_LANG_ID',
       u'PREF_COMM_LANG', u'PREF_COMM_LANG_SC', u'PREF_ADDR',
       u'Residence_Address_Line_1', u'Residence_Address_Line_2',
       u'Residence_Address_Line_3', u'Residence_City', u'Residence_Province',
       u'Residence_Country', u'Residence_Zip_CD', u'Residence_phone',
       u'residence_fax_number', u'Office_Address_Line_1',
       u'Office_Address_Line_2', u'Office_Address_Line_3', u'Office_City',
       u'OFFICE_PROVIENCE', u'OFFICE_COUNTRY', u'OFFICE__ZIP_CD',
       u'OFFICE_PHONE_NO', u'office_fax_number', u'Preferred_email_ID',
       u'Preferred_Comm_Channel', u'Preferred_Comm_Sub_Channel',
       u'Preferred_Comm_Sub_Channel_SC', u'PREF_CONTACT_TIME',
       u'Acquistion_Channel_ID', u'Acquistion_Channel_SC',
       u'Acquistion_Channel_Description', u'acquisition_subchannel_id',
       u'acquisition_subchannel_type_sc', u'acquisition_subchannel',
       u'INFLUENCE', u'fbck_user_FLG', u'fbck_following_CNT',
       u'fbck_follower_CNT', u'twt_user_FLG', u'twt_follower_CNT',
       u'twt_following_CNT', u'Interests_1', u'Interest_2', u'Friends_Count',
       u'credit_risk_score', u'credit_risk_rating', u'DRIVING_LICENSE_NO',
       u'BIRTH_MONTH', u'BIRTH_YEAR', u'BIRTH_QUARTER', u'PLACE_OF_BIRTH',
       u'COUNTRY_OF_BIRTH_SC', u'EVER_BANKRUPT_FLG',
       u'NO_TIMES_DELINQUENT_in_365_days', u'BLACKLISTED_FLG',
       u'NO_OF_DEPENDANTS', u'Record_created_By'],
      dtype='object')
'''

'''
Index([u'Transaction_Id', u'Invoice_Id', u'Order_Id', u'Customer_Id',
       u'Mdm_Customer_Id', u'Loyalty_Id', u'Gender', u'Age', u'Membership_Id',
       u'Membership_Type', u'Membership_SC', u'Product_Id', u'Channel_Id',
       u'Sub_Channel_Id', u'Brand_Cd', u'Gender_Age_Id', u'Size_Id',
       u'Color_Id', u'Campaign_Id', u'Campaign_Desc', u'Store_Id',
       u'Store_Short_Code', u'Store_Description', u'Sale_Dt', u'City',
       u'City_Id', u'City_Sc', u'Country_Id', u'Country_Sc', u'Country',
       u'Business_Week', u'Day', u'No_Of_Items', u'Shipment_Flg',
       u'Order_Item_Paidprice_Gross_Amt_', u'Order_Item_Listprice_Gross_Amt_',
       u'Currency', u'Discount_Percentage', u'Discount_Amt',
       u'Mode_Of_Payment', u'Quantity_Returned', u'No_Of_Items_After_Return',
       u'Cancel_Date', u'Expiry_Date', u'Cancel_Reason_Code',
       u'Cancel_Description', u'Return_Flag', u'Return_Dt', u'Return_Amt',
       u'Order_Returnpaid_Gross_Amt', u'Lastmodified_Dt', u'Sales_Rep_Name',
       u'Sales_Rep_Id', u'Fraud'],
      dtype='object')
'''
# Out:
# "\nIndex([u'Transaction_Id', u'Invoice_Id', u'Order_Id', u'Customer_Id',\n       u'Mdm_Customer_Id', u'Loyalty_Id', u'Gender', u'Age', u'Membership_Id',\n       u'Membership_Type', u'Membership_SC', u'Product_Id', u'Channel_Id',\n       u'Sub_Channel_Id', u'Brand_Cd', u'Gender_Age_Id', u'Size_Id',\n       u'Color_Id', u'Campaign_Id', u'Campaign_Desc', u'Store_Id',\n       u'Store_Short_Code', u'Store_Description', u'Sale_Dt', u'City',\n       u'City_Id', u'City_Sc', u'Country_Id', u'Country_Sc', u'Country',\n       u'Business_Week', u'Day', u'No_Of_Items', u'Shipment_Flg',\n       u'Order_Item_Paidprice_Gross_Amt_', u'Order_Item_Listprice_Gross_Amt_',\n       u'Currency', u'Discount_Percentage', u'Discount_Amt',\n       u'Mode_Of_Payment', u'Quantity_Returned', u'No_Of_Items_After_Return',\n       u'Cancel_Date', u'Expiry_Date', u'Cancel_Reason_Code',\n       u'Cancel_Description', u'Return_Flag', u'Return_Dt', u'Return_Amt',\n       u'Order_Returnpaid_Gross_Amt', u'Lastmodified_Dt', u'Sales_Rep_Name',\n       u'Sales_Rep_Id', u'Fraud'],\n      dtype='object')\n"

# %%
###Converting transaction_data columns into binary columns

for col_name in transaction_data.columns:
    if(transaction_data[col_name].dtype == 'object'):
        transaction_data[col_name]= transaction_data[col_name].astype('category')
        transaction_data[col_name] = transaction_data[col_name].cat.codes

# %%
##Looking out for null values
null_data = customer_data[customer_data.isnull().any(axis=1)]
display(null_data)
# Out:
#      CUSTOMER_ID LOYALTY_ID  MEMBERSHIP_TYPE__ID MEMBERSHIP_TYPE  \
# 0       76565665  LID877073                901.0            Gold
# 1       76565666  LID877029                  NaN             NaN
# 4       76565669  LID877001                902.0          Silver
# 5       76565670  LID877275                901.0            Gold
# 6       76565671  LID876961                  NaN             NaN
# 7       76565672  LID877158                903.0          Bronze
# 10      76565675  LID876903                  NaN             NaN
# 13      76565678  LID877395                  NaN             NaN
# 14      76565679  LID877184                903.0          Bronze
# 15      76565680  LID876955                  NaN             NaN
# 16      76565681  LID876749                  NaN             NaN
# 17      76565682  LID877078                903.0          Bronze
# 18      76565683        NaN                  NaN             NaN
# 20      76565685  LID877040                903.0          Bronze
# 22      76565687        NaN                  NaN             NaN
# 24      76565689  LID876896                  NaN             NaN
# 27      76565692  LID876934                  NaN             NaN
# 29      76565694  LID877420                902.0          Silver
# 30      76565695  LID877167                903.0          Bronze
# 31      76565696  LID877076                903.0          Bronze
# 32      76565697  LID877094                  NaN             NaN
# 33      76565698  LID876948                  NaN             NaN
# 35      76565700  LID877108                904.0        Platinum
# 40      76565705  LID876915                  NaN             NaN
# 41      76565706  LID877015                904.0        Platinum
# 42      76565707  LID877153                904.0        Platinum
# 47      76565712  LID876960                  NaN             NaN
# 48      76565713  LID877060                904.0        Platinum
# 49      76565714  LID877098                  NaN             NaN
# 50      76565715  LID876625                903.0          Bronze
# ..           ...        ...                  ...             ...
# 970     76566635  LID877343                903.0          Bronze
# 971     76566636  LID877271                904.0        Platinum
# 972     76566637  LID877383                903.0          Bronze
# 973     76566638  LID877307                903.0          Bronze
# 974     76566639  LID877466                903.0          Bronze
# 975     76566640  LID877258                902.0          Silver
# 976     76566641  LID877262                902.0          Silver
# 977     76566642  LID877539                  NaN             NaN
# 978     76566643  LID877478                904.0        Platinum
# 979     76566644  LID877214                904.0        Platinum
# 980     76566645  LID877266                902.0          Silver
# 981     76566646  LID877299                  NaN             NaN
# 982     76566647  LID877489                  NaN             NaN
# 983     76566648  LID877503                904.0        Platinum
# 984     76566649  LID877438                904.0        Platinum
# 985     76566650  LID877393                  NaN             NaN
# 986     76566651  LID877523                902.0          Silver
# 987     76566652  LID877524                901.0            Gold
# 988     76566653  LID877351                902.0          Silver
# 989     76566654  LID877374                902.0          Silver
# 990     76566655  LID877292                  NaN             NaN
# 991     76566656  LID877468                903.0          Bronze
# 992     76566657  LID877504                901.0            Gold
# 993     76566658  LID877454                903.0          Bronze
# 994     76566659  LID877244                904.0        Platinum
# 995     76566660  LID877405                904.0        Platinum
# 996     76566661  LID877306                903.0          Bronze
# 997     76566662  LID877204                901.0            Gold
# 998     76566663  LID877488                902.0          Silver
# 999     76566664  LID877217                901.0            Gold
#
#     MEMBERSHIP_TYPE_SC CUSTOMER_FLG            Customer_Type  \
# 0                  GLD            Y  Small/Medium Enterprise
# 1                  NaN            Y               Individual
# 4                  SLV            Y               Individual
# 5                  GLD            Y               Individual
# 6                  NaN            Y               Individual
# 7                  BRZ            Y               Individual
# 10                 NaN            Y               Individual
# 13                 NaN            Y  Small/Medium Enterprise
# 14                 BRZ            Y  Small/Medium Enterprise
# 15                 NaN            Y  Small/Medium Enterprise
# 16                 NaN            Y  Small/Medium Enterprise
# 17                 BRZ            Y  Small/Medium Enterprise
# 18                 NaN            N                      NaN
# 20                 BRZ            Y  Small/Medium Enterprise
# 22                 NaN            N                      NaN
# 24                 NaN            Y               Individual
# 27                 NaN            Y               Individual
# 29                 SLV            Y  Small/Medium Enterprise
# 30                 BRZ            Y  Small/Medium Enterprise
# 31                 BRZ            Y  Small/Medium Enterprise
# 32                 NaN            Y  Small/Medium Enterprise
# 33                 NaN            Y               Individual
# 35                 PLT            Y  Small/Medium Enterprise
# 40                 NaN            Y  Small/Medium Enterprise
# 41                 PLT            Y               Individual
# 42                 PLT            Y  Small/Medium Enterprise
# 47                 NaN            Y  Small/Medium Enterprise
# 48                 PLT            Y               Individual
# 49                 NaN            Y               Individual
# 50                 BRZ            Y               Individual
# ..                 ...          ...                      ...
# 970                BRZ            Y  Small/Medium Enterprise
# 971                PLT            Y  Small/Medium Enterprise
# 972                BRZ            Y  Small/Medium Enterprise
# 973                BRZ            Y               Individual
# 974                BRZ            Y  Small/Medium Enterprise
# 975                SLV            Y  Small/Medium Enterprise
# 976                SLV            Y  Small/Medium Enterprise
# 977                NaN            Y  Small/Medium Enterprise
# 978                PLT            Y  Small/Medium Enterprise
# 979                PLT            Y               Individual
# 980                SLV            Y  Small/Medium Enterprise
# 981                NaN            Y               Individual
# 982                NaN            Y  Small/Medium Enterprise
# 983                PLT            Y  Small/Medium Enterprise
# 984                PLT            Y               Individual
# 985                NaN            Y               Individual
# 986                SLV            Y  Small/Medium Enterprise
# 987                GLD            Y               Individual
# 988                SLV            Y  Small/Medium Enterprise
# 989                SLV            Y  Small/Medium Enterprise
# 990                NaN            Y               Individual
# 991                BRZ            Y               Individual
# 992                GLD            Y               Individual
# 993                BRZ            Y               Individual
# 994                PLT            Y               Individual
# 995                PLT            Y  Small/Medium Enterprise
# 996                BRZ            Y  Small/Medium Enterprise
# 997                GLD            Y               Individual
# 998                SLV            Y               Individual
# 999                GLD            Y  Small/Medium Enterprise
#
#      customer_type_id customer_type_sc behavior_segment        ...          \
# 0              1002.0              ENT       High Value        ...
# 1              1003.0             INDV        Low Value        ...
# 4              1003.0             INDV     Medium Value        ...
# 5              1003.0             INDV       High Value        ...
# 6              1003.0             INDV        Low Value        ...
# 7              1003.0             INDV       High Value        ...
# 10             1003.0             INDV     Medium Value        ...
# 13             1002.0              ENT        Low Value        ...
# 14             1002.0              ENT     Medium Value        ...
# 15             1002.0              ENT     Medium Value        ...
# 16             1002.0              ENT     Medium Value        ...
# 17             1002.0              ENT     Medium Value        ...
# 18                NaN              NaN              NaN        ...
# 20             1002.0              ENT       High Value        ...
# 22                NaN              NaN              NaN        ...
# 24             1003.0             INDV       High Value        ...
# 27             1003.0             INDV        Low Value        ...
# 29             1002.0              ENT        Low Value        ...
# 30             1002.0              ENT        Low Value        ...
# 31             1002.0              ENT       High Value        ...
# 32             1002.0              ENT       High Value        ...
# 33             1003.0             INDV     Medium Value        ...
# 35             1002.0              ENT       High Value        ...
# 40             1002.0              ENT        Low Value        ...
# 41             1003.0             INDV     Medium Value        ...
# 42             1002.0              ENT        Low Value        ...
# 47             1002.0              ENT       High Value        ...
# 48             1003.0             INDV       High Value        ...
# 49             1003.0             INDV     Medium Value        ...
# 50             1003.0             INDV       High Value        ...
# ..                ...              ...              ...        ...
# 970            1002.0              ENT        Low Value        ...
# 971            1002.0              ENT       High Value        ...
# 972            1002.0              ENT        Low Value        ...
# 973            1003.0             INDV        Low Value        ...
# 974            1002.0              ENT     Medium Value        ...
# 975            1002.0              ENT       High Value        ...
# 976            1002.0              ENT        Low Value        ...
# 977            1002.0              ENT     Medium Value        ...
# 978            1002.0              ENT       High Value        ...
# 979            1003.0             INDV       High Value        ...
# 980            1002.0              ENT        Low Value        ...
# 981            1003.0             INDV     Medium Value        ...
# 982            1002.0              ENT        Low Value        ...
# 983            1002.0              ENT        Low Value        ...
# 984            1003.0             INDV        Low Value        ...
# 985            1003.0             INDV        Low Value        ...
# 986            1002.0              ENT        Low Value        ...
# 987            1003.0             INDV     Medium Value        ...
# 988            1002.0              ENT       High Value        ...
# 989            1002.0              ENT        Low Value        ...
# 990            1003.0             INDV       High Value        ...
# 991            1003.0             INDV     Medium Value        ...
# 992            1003.0             INDV       High Value        ...
# 993            1003.0             INDV     Medium Value        ...
# 994            1003.0             INDV       High Value        ...
# 995            1002.0              ENT     Medium Value        ...
# 996            1002.0              ENT       High Value        ...
# 997            1003.0             INDV     Medium Value        ...
# 998            1003.0             INDV        Low Value        ...
# 999            1002.0              ENT       High Value        ...
#
#     BIRTH_MONTH  BIRTH_YEAR BIRTH_QUARTER    PLACE_OF_BIRTH  \
# 0         April        2004             2          Bellevue
# 1      December        1984             4           Jackson
# 4       January        1992             1       Los Angeles
# 5      February        2004             1           Fremont
# 6          July        1986             3        Scottsdale
# 7         April        1989             2         Santa Ana
# 10         July        1993             3       Chattanooga
# 13    September        1985             3          Stamford
# 14     November        1993             4         Charlotte
# 15     December        1986             4           Norfolk
# 16     November        1998             4           Yonkers
# 17         June        1988             2          St. Paul
# 18          NaN           0             0               NaN
# 20     February        1983             1          Surprise
# 22          NaN           0             0               NaN
# 24    September        2000             3       Bakersfield
# 27     December        1983             4          Honolulu
# 29         July        2000             3            Aurora
# 30     December        1985             4           Augusta
# 31        March        2003             1            Aurora
# 32      October        1992             4          Surprise
# 33       August        1989             3         St. Louis
# 35        March        1985             1           Jackson
# 40      October        2002             4           Atlanta
# 41      January        2003             1             Tempe
# 42        March        1978             1             Fargo
# 47         July        1991             3           Augusta
# 48        April        1996             2             Salem
# 49       August        2002             3         Worcester
# 50       August        1998             3       Los Angeles
# ..          ...         ...           ...               ...
# 970    December        1991             4           Hialeah
# 971        July        1995             3      Fayetteville
# 972        June        1996             2        Montgomery
# 973    February        1998             1          Columbus
# 974    December        2001             4           Orlando
# 975        June        1991             2       Chattanooga
# 976        June        1996             2     Moreno Valley
# 977    December        2003             4       Kansas City
# 978         May        1997             2      Cedar Rapids
# 979        July        1999             3         Ann Arbor
# 980     October        1998             4        Manchester
# 981    February        1980             1       Sioux Falls
# 982       April        2002             2      Fort Collins
# 983    December        1993             4            Aurora
# 984        July        1986             3         Charlotte
# 985        June        1980             2         Anchorage
# 986    November        1987             4    St. Petersburg
# 987        June        1978             2        Alexandria
# 988        July        1985             3           Lincoln
# 989    December        1986             4           Yonkers
# 990       March        1996             1      Murfreesboro
# 991    December        1985             4          Honolulu
# 992        June        1983             2            Tucson
# 993        July        2001             3           Raleigh
# 994         May        1996             2  West Valley City
# 995   September        1983             3            Mobile
# 996    December        1997             4              Cary
# 997       March        1985             1           Orlando
# 998     October        1997             4         Las Vegas
# 999    February        1995             1         Ann Arbor
#
#     COUNTRY_OF_BIRTH_SC  EVER_BANKRUPT_FLG  NO_TIMES_DELINQUENT_in_365_days  \
# 0                    US                  N                                1
# 1                    US                  N                                1
# 4                    US                  N                                1
# 5                    US                  N                                0
# 6                    US                  N                                0
# 7                    US                  N                                0
# 10                   US                  N                                1
# 13                   US                  N                                1
# 14                   US                  N                                1
# 15                   US                  N                                1
# 16                   US                  N                                1
# 17                   US                  N                                0
# 18                  NaN                NaN                                0
# 20                   US                  N                                0
# 22                  NaN                NaN                                0
# 24                   US                  N                                0
# 27                   US                  N                                0
# 29                   US                  N                                1
# 30                   US                  N                                1
# 31                   US                  N                                0
# 32                   US                  N                                1
# 33                   US                  N                                0
# 35                   US                  N                                1
# 40                   US                  N                                1
# 41                   US                  N                                1
# 42                   US                  N                                1
# 47                   US                  N                                0
# 48                   US                  N                                0
# 49                   US                  N                                1
# 50                   US                  N                                0
# ..                  ...                ...                              ...
# 970                  US                  N                                1
# 971                  US                  N                                1
# 972                  US                  N                                0
# 973                  US                  N                                0
# 974                  US                  N                                0
# 975                  US                  N                                1
# 976                  US                  N                                1
# 977                  US                  N                                1
# 978                  US                  N                                0
# 979                  US                  N                                1
# 980                  US                  N                                1
# 981                  US                  N                                0
# 982                  US                  N                                1
# 983                  US                  N                                1
# 984                  US                  N                                0
# 985                  US                  N                                0
# 986                  US                  N                                0
# 987                  US                  N                                0
# 988                  US                  N                                1
# 989                  US                  N                                0
# 990                  US                  N                                1
# 991                  US                  N                                0
# 992                  US                  N                                1
# 993                  US                  N                                1
# 994                  US                  N                                0
# 995                  US                  N                                0
# 996                  US                  N                                0
# 997                  US                  N                                1
# 998                  US                  N                                1
# 999                  US                  N                                1
#
#     BLACKLISTED_FLG NO_OF_DEPENDANTS  Record_created_By
# 0                 N                3                 \r
# 1                 N                1                 \r
# 4                 N                1                 \r
# 5                 N                2                 \r
# 6                 N                1                 \r
# 7                 N                2                 \r
# 10                N                3                 \r
# 13                N                3                 \r
# 14                N                2                 \r
# 15                N                1                 \r
# 16                N                2                 \r
# 17                N                3                 \r
# 18              NaN                0                 \r
# 20                N                1                 \r
# 22              NaN                0                 \r
# 24                N                2                 \r
# 27                N                3                 \r
# 29                N                2                 \r
# 30                N                1                 \r
# 31                N                3                 \r
# 32                N                2                 \r
# 33                N                2                 \r
# 35                N                1                 \r
# 40                N                1                 \r
# 41                N                1                 \r
# 42                N                2                 \r
# 47                N                3                 \r
# 48                N                3                 \r
# 49                N                3                 \r
# 50                N                3                 \r
# ..              ...              ...                ...
# 970               N                2                 \r
# 971               N                2                 \r
# 972               N                2                 \r
# 973               N                1                 \r
# 974               N                1                 \r
# 975               N                2                 \r
# 976               N                3                 \r
# 977               N                2                 \r
# 978               N                1                 \r
# 979               N                2                 \r
# 980               N                3                 \r
# 981               N                3                 \r
# 982               N                3                 \r
# 983               N                3                 \r
# 984               N                3                 \r
# 985               N                2                 \r
# 986               N                3                 \r
# 987               N                3                 \r
# 988               N                2                 \r
# 989               N                1                 \r
# 990               N                3                 \r
# 991               N                1                 \r
# 992               N                3                 \r
# 993               N                2                 \r
# 994               N                3                 \r
# 995               N                3                 \r
# 996               N                1                 \r
# 997               N                1                 \r
# 998               N                3                 \r
# 999               N                3                 \r
#
# [726 rows x 94 columns]

# %%
'''
Joining all the 3 sheets
'''
#caller.join(other.set_index('key'), on='key')
f1=sales_data.join(transaction_data.set_index('Transaction_Id'),on='Transaction_Id')
master_data = f1.join(customer_data.set_index('CUSTOMER_ID'),on='Customer_Id')

# %%
master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947 entries, 0 to 946
# Columns: 157 entries, Transaction_Id to Record_created_By
# dtypes: datetime64[ns](3), float64(13), int64(39), int8(10), object(92)
# memory usage: 1.1+ MB

# %%
display(master_data.head())
# Out:
#    Transaction_Id  Invoice_Id  Order_Id  Customer_Id  Mdm_Customer_Id  \
# 0          234825       88371     88371     76565900        954421840
# 1          234666       88234     88234     76566122        965982087
# 2          234823       88153     88153     76565906        953091566
# 3          235342       87867     87867     76566458        924245622
# 4          234739       87945     87945     76566387        966653489
#
#   Loyalty_Id  Gender  Age  Membership_Id Membership_Type        ...         \
# 0  LID876561  FEMALE   26          904.0        Platinum        ...
# 1        NaN    MALE   22            NaN             NaN        ...
# 2  LID876543    MALE   19          904.0        Platinum        ...
# 3  LID876557    MALE   26          901.0            Gold        ...
# 4  LID876640    MALE   37          901.0            Gold        ...
#
#   BIRTH_MONTH  BIRTH_YEAR  BIRTH_QUARTER  PLACE_OF_BIRTH COUNTRY_OF_BIRTH_SC  \
# 0        July        1984              3           Miami                  US
# 1        June        1984              2          Newark                  US
# 2        June        1986              2       Anchorage                  US
# 3     January        1991              1       Anchorage                  US
# 4        July        1977              3        Columbia                  US
#
#    EVER_BANKRUPT_FLG  NO_TIMES_DELINQUENT_in_365_days  BLACKLISTED_FLG  \
# 0                  N                                1                N
# 1                  N                                0                N
# 2                  N                                1                N
# 3                  N                                1                N
# 4                  N                                1                N
#
#    NO_OF_DEPENDANTS Record_created_By
# 0                 3                \r
# 1                 1                \r
# 2                 3                \r
# 3                 3                \r
# 4                 3                \r
#
# [5 rows x 157 columns]

# %%
'''
Removing the following columns as these are redundant columns and won't help in our analysis .
'''
column_list_removal=['City','City_Id','MEMBERSHIP_TYPE__ID','MEMBERSHIP_TYPE','Customer_Type','customer_type_id','SALUTATION','GENDER_ID','GENDER_SC','CUSTOMER_STATUS_ID','CUSTOMER_STATUS','CUSTOMER_CREATED_DT','DEVICE_ID','APP_ID','MARITAL_STATUS_ID','MARITAL_STATUS','ANNIVERSARY_DT','INCOME_RANGE','PROFESSION','PROFESSION_TYPE_ID','PREF_COMM_LANG_ID','PREF_COMM_LANG','Residence_Country','Preferred_Comm_Sub_Channel','Acquistion_Channel_ID','Acquistion_Channel_Description','acquisition_subchannel_id','acquisition_subchannel','COUNTRY_OF_BIRTH_SC','Membership_Id','Membership_Type','Campaign_Desc','Store_Id','Store_Description','Country_Id','Country','Currency','Cancel_Description','Sales_Rep_Id']

# dividing test and train data 
for column_name in column_list_removal:
    master_data=master_data.drop(column_name,axis=1)

# %%
master_data.info()
len(column_list_removal)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947 entries, 0 to 946
# Columns: 118 entries, Transaction_Id to Record_created_By
# dtypes: datetime64[ns](3), float64(3), int64(36), int8(10), object(66)
# memory usage: 808.3+ KB
# 39

# %%
table = master_data.pivot_table(master_data, index=['GENDER'],columns=['Fraud'], aggfunc=np.sum)
print(table)
# Out:
#         Multiple Shipping Addresses.        AGE          Age        \
# Fraud                             No Yes     No   Yes     No   Yes
# GENDER
# FEMALE                            32   9  11154  1634  10944  1683
# MALE                              35   7  11786  1554  11896  1667
#
#        BIRTH_QUARTER      BIRTH_YEAR          ...  credit_risk_score         \
# Fraud             No  Yes         No     Yes  ...                 No    Yes
# GENDER                                        ...
# FEMALE           953  152     768057  117460  ...             192992  27765
# MALE            1059  143     828078  119610  ...             217644  29552
#
#        fbck_follower_CNT       fbck_following_CNT       twt_follower_CNT  \
# Fraud                 No   Yes                 No   Yes               No
# GENDER
# FEMALE              7209  1018               7477  1128             6894
# MALE                7219  1172               8548  1092             6782
#
#              twt_following_CNT
# Fraud    Yes                No   Yes
# GENDER
# FEMALE  1005              6689   917
# MALE     915              6457  1025
#
# [2 rows x 98 columns]

# %%
categorical_variables=''

# %%
for col_name in master_data.columns:
    master_data[col_name].dtype == 'object'
    print(col_name)
# Out:
# Transaction_Id
# Invoice_Id
# Order_Id
# Customer_Id
# Mdm_Customer_Id
# Loyalty_Id
# Gender
# Age
# Membership_SC
# Product_Id
# Channel_Id
# Sub_Channel_Id
# Brand_Cd
# Gender_Age_Id
# Size_Id
# Color_Id
# Campaign_Id
# Store_Short_Code
# Sale_Dt
# City_Sc
# Country_Sc
# Business_Week
# Day
# No_Of_Items
# Shipment_Flg
# Order_Item_Paidprice_Gross_Amt_
# Order_Item_Listprice_Gross_Amt_
# Discount_Percentage
# Discount_Amt
# Mode_Of_Payment
# Quantity_Returned
# No_Of_Items_After_Return
# Cancel_Date
# Expiry_Date
# Cancel_Reason_Code
# Return_Flag
# Return_Dt
# Return_Amt
# Order_Returnpaid_Gross_Amt
# Lastmodified_Dt
# Sales_Rep_Name
# Fraud
# First Time Customers.
# Bigger than Average Orders.
# Fast Shipping
# Unusual Location.
# Large quantity of Same Product .
#  Multiple Shipping Addresses.
# Shipping and Billing Address are not the same.
# Several Cards used from the Same Ip Address.
# Payment Information typed with Capital letters.
# Many Transactions in a short time period.
# LOYALTY_ID
# MEMBERSHIP_TYPE_SC
# CUSTOMER_FLG
# customer_type_sc
# behavior_segment
# GENDER
# BIRTH_DATE
# AGE
# age_at_joining
# age_range
# PLACE_OF_BITRH
# CUSTOMER_STATUS_SC
# LOYALITY_FLG
# MARITAL_STATUS_SC
# INCOME
# PROFESSION_TYPE_SC
# education
# REGION
# LANGUAGE
# PREF_COMM_LANG_SC
# PREF_ADDR
# Residence_Address_Line_1
# Residence_Address_Line_2
# Residence_Address_Line_3
# Residence_City
# Residence_Province
# Residence_Zip_CD
# Residence_phone
# residence_fax_number
# Office_Address_Line_1
# Office_Address_Line_2
# Office_Address_Line_3
# Office_City
# OFFICE_PROVIENCE
# OFFICE_COUNTRY
# OFFICE__ZIP_CD
# OFFICE_PHONE_NO
# office_fax_number
# Preferred_email_ID
# Preferred_Comm_Channel
# Preferred_Comm_Sub_Channel_SC
# PREF_CONTACT_TIME
# Acquistion_Channel_SC
# acquisition_subchannel_type_sc
# INFLUENCE
# fbck_user_FLG
# fbck_following_CNT
# fbck_follower_CNT
# twt_user_FLG
# twt_follower_CNT
# twt_following_CNT
# Interests_1
# Interest_2
# Friends_Count
# credit_risk_score
# credit_risk_rating
# DRIVING_LICENSE_NO
# BIRTH_MONTH
# BIRTH_YEAR
# BIRTH_QUARTER
# PLACE_OF_BIRTH
# EVER_BANKRUPT_FLG
# NO_TIMES_DELINQUENT_in_365_days
# BLACKLISTED_FLG
# NO_OF_DEPENDANTS
# Record_created_By

# %%
#Converting data type to int
convert_to_int=['Transaction_Id','Invoice_Id','Order_Id','Customer_Id','Age','Product_Id','Business_Week','No_Of_Items',
                'Order_Item_Paidprice_Gross_Amt_','Order_Item_Listprice_Gross_Amt_','Discount_Percentage',
                'Discount_Amt','Quantity_Returned','No_Of_Items_After_Return','Return_Amt','Order_Returnpaid_Gross_Amt',
                'INCOME','Residence_Zip_CD','fbck_following_CNT','fbck_follower_CNT','twt_follower_CNT','twt_following_CNT','Friends_Count','credit_risk_score','BIRTH_QUARTER','BIRTH_YEAR']



convert_to_string=['Loyalty_Id','City','LOYALTY_ID','Residence_Address_Line_1','Residence_Address_Line_2','Residence_Address_Line_3','Residence_City','Residence_Province','Residence_phone','residence_fax_number','Office_Address_Line_1','Office_Address_Line_2','Office_Address_Line_3','Office_City','OFFICE_PROVIENCE','OFFICE_COUNTRY','OFFICE__ZIP_CD','OFFICE_PHONE_NO','Preferred_email_ID','Interests_1','Interest_2','DRIVING_LICENSE_NO','BIRTH_MONTH']



ordinals=['Membership_SC','Sub_Channel_Id','Brand_Cd','Gender_Age_Id','Size_Id','Color_Id','Campaign_Id','Store_Short_Code','City_Sc','Country_Sc','Mode_Of_Payment','Cancel_Reason_Code','Sales_Rep_Name','PROFESSION_TYPE_SC','education','REGION','LANGUAGE','MARITAL_STATUS_SC','Preferred_Comm_Channel','Preferred_Comm_Sub_Channel_SC','PREF_CONTACT_TIME','Acquistion_Channel_SC','acquisition_subchannel_type_sc','INFLUENCE','credit_risk_rating',]



binary_category=['Gender',,'Channel_Id','Shipment_Flg','Return_Flag','Fraud','First Time Customers.'
                 ,'Bigger than Average Orders.','Fast Shipping','Unusual Location.','Large quantity of Same Product .',
                 ' Multiple Shipping Addresses.','Shipping and Billing Address are not the same',
                 'Several Cards used from the Same Ip Address.','Several Cards used from the Same Ip Address.','Payment Information typed with Capital letters.','Many Transactions in a short time period.','PREF_COMM_LANG_SC',
                 'PREF_ADDR','fbck_user_FLG','twt_user_FLG','EVER_BANKRUPT_FLG','NO_TIMES_DELINQUENT_in_365_days','BLACKLISTED_FLG']


Record_created_BY<--REMOVE THIS COLUMN





to_date=['Sale_Dt','Cancel_Date','Expiry_Date','Return_Dt','Lastmodified_Dt']


master_data['Transaction_Id'].astype('int')
master_data['Transaction_Id'].dtype
# Out:
#   File "<ipython-input-17-e8dedb3cdf3b>", line 17
#     binary_category=['Gender',,'Channel_Id','Shipment_Flg','Return_Flag','Fraud','First Time Customers.'
#                               ^
# SyntaxError: invalid syntax

# %%
f,ax=plt.subplots(figsize=(15, 15))
sns.heatmap(data=transaction_data.corr(),annot=True,linewidths=.5,fmt= '.1f',ax=ax)
plt.show()

# %%
train_test_split
